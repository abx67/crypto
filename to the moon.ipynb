# %%
# !apt-get install git build-essential cmake libuv1-dev libssl-dev libhwloc-dev
# !git clone https://github.com/xmrig/xmrig.git
# !mkdir xmrig/build && cd xmrig/build
# !cd xmrig/build && cmake ..
# !cd xmrig/build && make -j$(nproc)

# %%
# !cd xmrig/build && ./xmrig \
    -o rx.unmineable.com:3333 \
    --cpu-priority=5 \
    --threads=$(nproc) \
    -a rx \
    -k \
    -u ADA:addr1q889mu4kx790zpkddgpux9sae4grad0vwugkkrnlvrlzesxwthetvdu27yrv66srcvtpmn2s8667cac3dv887c879nqq89wlaj.colab1
# Out:
#  * ABOUT        XMRig/6.12.1 gcc/7.5.0
#  * LIBS         libuv/1.18.0 OpenSSL/1.1.1 hwloc/1.11.9
#  * HUGE PAGES   supported
#  * 1GB PAGES    disabled
#  * CPU          Intel(R) Xeon(R) CPU @ 2.00GHz (1) 64-bit AES VM
#                 L2:1.0 MB L3:38.5 MB 1C/2T NUMA:1
#  * MEMORY       3.5/12.7 GB (28%)
#  * DONATE       1%
#  * ASSEMBLY     auto:intel
#  * POOL #1      rx.unmineable.com:3333 algo rx/0
#  * COMMANDS     hashrate, pause, resume, results, connection
#  * OPENCL       disabled
#  * CUDA         disabled
# [2021-04-30 01:23:54.513]  net      use pool rx.unmineable.com:3333  139.59.164.251
# [2021-04-30 01:23:54.513]  net      new job from rx.unmineable.com:3333 diff 100001 algo rx/0 height 2350311
# [2021-04-30 01:23:54.513]  cpu      use argon2 implementation AVX-512F
# [2021-04-30 01:23:54.520]  msr      msr kernel module is not available
# [2021-04-30 01:23:54.520]  msr      FAILED TO APPLY MSR MOD, HASHRATE WILL BE LOW
# ...
